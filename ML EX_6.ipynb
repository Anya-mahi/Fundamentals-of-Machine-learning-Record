# %%
import numpy as np
import pandas as pd
from sklearn import svm
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# %%
recipes=pd.read_csv('/content/recipes_muffins_cupcakes.csv')
recipes.head()
recipes.shape
# Out:
# (20, 9)

# %%
sns.lmplot(x="Sugar", y="Flour", data=recipes, hue="Type", palette="Set1", fit_reg=False, scatter_kws={"s": 70})

# %%
Sugar_butter=recipes[["Sugar","Flour"]].values
Sugar_butter=recipes[["Sugar","Flour"]].values
type_label=np.where(recipes["Type"]=="Muffin",0,1)
model=svm.SVC(kernel="linear")
model.fit(Sugar_butter,type_label)
# Out:
# SVC(kernel='linear')

# %%
#SVC(kernel=linear)
w=model.coef_[0] #seperating the hyperplane
a=-w[0]/w[1]
xx=np.linspace(5,30)
yy=a*xx-(model.intercept_[0]/w[1])
b=model.support_vectors_[0] #plot to seperate hyperplane that pass
yy_down=a*xx+(b[1]-a*b[0])
b=model.support_vectors_[-1]
yy_up=a*xx+(b[1]-a*b[0])

# %%
# Pass the DataFrame 'recipes' to the 'data' argument, instead of the string "recipes"
sns.lmplot(x="Sugar", y="Flour", data=recipes, hue="Type", palette="Set1", fit_reg=False, scatter_kws={"s": 70})
plt.plot(xx,yy,linewidth=2,color="black")
a=-w[0]/w[1]
xx=np.linspace(5,30)
yy=a*xx-(model.intercept_[0]/w[1])
b=model.support_vectors_[0] #plot to seperate hyperplane that pass
yy_down=a*xx+(b[1]-a*b[0])
sugar_butter=recipes[["Sugar","Flour"]].values
type_label=np.where(recipes["Type"]=="Muffin",0,1)
model=svm.SVC(kernel="linear")
model.fit(sugar_butter,type_label)
# Out:
# SVC(kernel='linear')

# %%
#SVC(kernel=linear)
w=model.coef_[0] #seperating the hyperplane
a=-w[0]/w[1]
xx=np.linspace(5,30)
yy=a*xx-(model.intercept_[0]/w[1])
b=model.support_vectors_[0] #plot to seperate hyperplane that pass
yy_down=a*xx+(b[1]-a*b[0])
b=model.support_vectors_[-1]
yy_up=a*xx+(b[1]-a*b[0])
sns.lmplot(x="Sugar", y="Flour", data=recipes, hue="Type", palette="Set1", fit_reg=False, scatter_kws={"s": 70})
plt.plot(xx,yy,linewidth=2,color="black")
a=-w[0]/w[1]
xx=np.linspace(5,30)
yy=a*xx-(model.intercept_[0]/w[1])
b=model.support_vectors_[0] #plot to seperate hyperplane that pass
yy_down=a*xx+(b[1]-a*b[0])
b=model.support_vectors_[-1]
yy_up=a*xx+(b[1]-a*b[0])
sns.lmplot("Sugar","Flour",data=recipes,hue="Type",palette="Set1",fit_reg=False,scatter_kws={"s":70})
plt.plot(xx,yy,linewidth=2,color="black")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b14dba35505c> in <cell line: 19>()
#      17 b=model.support_vectors_[-1]
#      18 yy_up=a*xx+(b[1]-a*b[0])
# ---> 19 sns.lmplot("Sugar","Flour",data=recipes,hue="Type",palette="Set1",fit_reg=False,scatter_kws={"s":70})
#      20 plt.plot(xx,yy,linewidth=2,color="black")
#
# TypeError: lmplot() got multiple values for argument 'data'

# %%
scatterkws={"s":70}
plt.plot(xx,yy,linewidth=2,color='black')
sns.lmplot(x="Sugar", y="Flour", data=recipes, hue="Type", palette="Set1", fit_reg=False, scatter_kws={"s": 70})
plt.plot(xx,yy,linewidth=2,color='black')
plt.plot(xx,yy_down, 'k--')
plt.plot(xx,yy,linewidth=2,color='black')
plt.plot(xx,yy_down,'k--')

# %%
plt.plot(xx,yy_up,'k--')
plt.scatter(model.support_vectors_[:,0],model.support_vectors_[:,-1],s=80,facecolors='none')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
x_train,x_test,y_train,y_test =train_test_split(sugar_butter,type_label,test_size=0.2)
model1=svm.SVC(kernel='linear') # Changed:  kernel=linear to kernel='linear'
model1.fit(x_train,y_train)
pred = model1.predict(x_test)
print(pred)
# Out:
# [0 0 0 0]

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[3 0]
#  [1 0]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.75         4
#    macro avg       0.38      0.50      0.43         4
# weighted avg       0.56      0.75      0.64         4
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
